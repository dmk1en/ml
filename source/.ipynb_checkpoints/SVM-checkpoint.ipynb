# %%
from IPython.display import display, Markdown
markdown_content = """
# Email Classifer using SVM
"""
display(Markdown(markdown_content))
# Out:
# # Email Classifer using SVM

# %%
markdown_content = """
## 1.Import library and read file csv
"""
display(Markdown(markdown_content))
# Out:
# ## 1.Import library and read file csv

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import nltk
import string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
ps = PorterStemmer()
df = pd.read_csv('D:/email-spam/src/preprocessing/tfidf_output_cleaned.csv')
df_copy = df.copy()
df_copy
# Out:
#       Label                                            Message  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5155      1  This is the 2nd time we have tried 2 contact u...
# 5156      0              Will Ì_ b going to esplanade fr home?
# 5157      0  Pity, * was in mood for that. So...any other s...
# 5158      0  The guy did some bitching but I acted like i'd...
# 5159      0                         Rofl. Its true to its name
#
#                                             imp_feature
# 0     go jurong point crazi avail bugi n great world...
# 1                                 ok lar joke wif u oni
# 2     free entri 2 wkli comp win fa cup final tkt 21...
# 3                   u dun say earli hor u c alreadi say
# 4                  nah think goe usf live around though
# ...                                                 ...
# 5155  2nd time tri 2 contact u pound prize 2 claim e...
# 5156                              b go esplanad fr home
# 5157                                  piti mood suggest
# 5158  guy bitch act like interest buy someth els nex...
# 5159                                     rofl true name
#
# [5160 rows x 3 columns]

# %%
markdown_content = """
## 2.Split data into 2 parts to train and test
"""
display(Markdown(markdown_content))
# Out:
# ## 2.Split data into 2 parts to train and test

# %%
X = df_copy['imp_feature']
y = df_copy['Label']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
# Convert a pandas Series to a DataFrame
X_train_series = pd.Series(X_train)
X_train_df = X_train_series.to_frame()


# Tạo RandomOverSampler
oversampler = RandomOverSampler(random_state=42)

# Áp dụng oversampling cho dữ liệu huấn luyện
X_train_resampled, y_train_resampled = oversampler.fit_resample(X_train_df, y_train)
X_train_resampled = X_train_resampled.squeeze()
#X_train_resampled,  y_train_resampled
print(X_train)
num_spam = y_train_resampled[y_train_resampled == 1].shape[0]
num_ham = y_train_resampled[y_train_resampled == 0].shape[0]
# Out:
# 2167                                check head drop stuff
# 3862    hiya u like hlday pic look horribl took mo how...
# 1424                      sent email address incomm right
# 326     call germani 1 penc per minut call fix line vi...
# 604                                 call said choos futur
#                               ...
# 4426    weekli tone readi download week new tone inclu...
# 466                 ok gon na head usf like fifteen minut
# 3092    moon come color dream star make music sm give ...
# 3772    u gd lor go shop got stuff u wan 2 watch infer...
# 860     remind download content alreadi paid goto http...
# Name: imp_feature, Length: 3870, dtype: object
# Số lượng email spam trước Oversampling: 3372
# Số lượng email ham trước Oversampling: 3372

# %%
labels = ['Spam', 'Ham']
sizes = [num_spam, num_ham]
colors = ['red', 'green']
explode = (0.1, 0)  # Tách phần Spam ra một chút

# Vẽ biểu đồ tròn
plt.figure(figsize=(8, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')  # Đảm bảo biểu đồ tròn
plt.title('Distribution of Email Spam vs. Ham')
plt.show()

# %%
markdown_content = """
## 3.Model
"""
display(Markdown(markdown_content))
# Out:
# ## 3.Model

# %%
markdown_content = """
### 3.Build Model
"""
display(Markdown(markdown_content))
# Out:
# ### 3.Build Model

# %%
print(X_train)
print(X_train_resampled)
# Out:
# 2167                                check head drop stuff
# 3862    hiya u like hlday pic look horribl took mo how...
# 1424                      sent email address incomm right
# 326     call germani 1 penc per minut call fix line vi...
# 604                                 call said choos futur
#                               ...
# 4426    weekli tone readi download week new tone inclu...
# 466                 ok gon na head usf like fifteen minut
# 3092    moon come color dream star make music sm give ...
# 3772    u gd lor go shop got stuff u wan 2 watch infer...
# 860     remind download content alreadi paid goto http...
# Name: imp_feature, Length: 3870, dtype: object
# 0                                   check head drop stuff
# 1       hiya u like hlday pic look horribl took mo how...
# 2                         sent email address incomm right
# 3       call germani 1 penc per minut call fix line vi...
# 4                                   call said choos futur
#                               ...
# 6739    last chanc 2 claim ur worth discount ye 85023 ...
# 6740    8007 free 1st week no1 nokia tone 4 ur mob eve...
# 6741    dear voucher holder claim week offer pc pleas ...
# 6742    summer final fanci chat flirt sexi singl yr ar...
# 6743    freemsg feelin kinda lnli hope u like 2 keep c...
# Name: imp_feature, Length: 6744, dtype: object

# %%
tfidf = TfidfVectorizer()
feature = tfidf.fit_transform(X_train_resampled)
tuned_parameters = {'kernel':['linear','rbf'],'gamma':[1e-3,1e-4], 'C':[1,10,100,1000]}
model = GridSearchCV(svm.SVC(),tuned_parameters)
model.fit(feature, y_train_resampled)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001],
#                          'kernel': ['linear', 'rbf']})

# %%
markdown_content = """
### 3.Check spam
"""
display(Markdown(markdown_content))
# Out:
# ### 3.Check spam

# %%
y_pred_train_def = model.predict(tfidf.transform(X_train_resampled))
y_pred_test_def = model.predict(tfidf.transform(X_test))

print("Train: ", accuracy_score(y_train_resampled, y_pred_train_def))
print("Test: ", accuracy_score(y_test, y_pred_test_def))
# Out:
# Train:  0.9997034400948992
# Test:  0.9790697674418605

# %%
markdown_content = """
### 4.Get predict and evaluate the model
"""
display(Markdown(markdown_content))
# Out:
# ### 4.Get predict and evaluate the model

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
x_test = tfidf.transform(X_test)
x_pred = model.predict(x_test)

def perform(y_pred):
    print("Precision : ", precision_score(y_test, y_pred))
    print("Recall : ", recall_score(y_test, y_pred))
    print("Accuracy Score : ", accuracy_score(y_test, y_pred))
    print("F1 Score : ", f1_score(y_test, y_pred))

perform(x_pred)
# Out:
# Precision :  0.9571428571428572
# Recall :  0.864516129032258
# Accuracy Score :  0.9790697674418605
# F1 Score :  0.9084745762711864

# %%
markdown_content = """
### 4.UI
"""
display(Markdown(markdown_content))
# Out:
# ### 4.UI

# %%
import pickle
filename = 'finalized_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
from tkinter import *
import tkinter as tk
import pickle

 
spam_model = pickle.load(open("D:/email-spam/src/source/finalized_model.sav",'rb'))

 
def check_spam():
    text = spam_text_Entry.get()
    is_spam = spam_model.predict(tfidf.transform([text]))
    if is_spam == 1:
        print("text is spam")
        my_string_var.set("Result: text is spam")
    else:
        print("text is not spam")
        my_string_var.set("Result: text is not spam")
win = Tk()
 
win.geometry("400x600")
win.configure(background="cyan")
win.title("Sms Spam Detector")
 
title = Label(win, text="SMS Spam Detector", bg="gray",width="300",height="2",fg="white",font=("Calibri 20 bold italic underline")).pack()
 
spam_text = Label(win, text="Enter your Text: ",bg="cyan", font=("Verdana 12")).place(x=12,y=100)
spam_text_Entry = Entry(win, textvariable=spam_text,width=33)
spam_text_Entry.place(x=155, y=105)
 
my_string_var = StringVar()
my_string_var.set("Result: ")
 
print_spam = Label(win, textvariable=my_string_var,bg="cyan", font=("Verdana 12")).place(x=12,y=200)
 
Button = Button(win, text="Submit",width="12",height="1",activebackground="red",bg="Pink",command=check_spam,font=("Verdana 12")).place(x=12,y=150)
 
win.mainloop()
# Out:
# text is not spam

# %%
def func(doc):  # n_jobs in GridSearch does not support lambda function
    return doc

tfidf = TfidfVectorizer() 

tfidf.fit(X_train_resampled)
# Out:
# TfidfVectorizer()

# %%
tfidf.vocabulary_
# Out:
# {'check': 1286,
#  'head': 2483,
#  'drop': 1793,
#  'stuff': 4833,
#  'hiya': 2539,
#  'like': 3045,
#  'hlday': 2541,
#  'pic': 3843,
#  'look': 3099,
#  'horribl': 2580,
#  'took': 5131,
#  'mo': 3356,
#  'how': 2592,
#  'camp': 1195,
#  'amrca': 688,
#  'thing': 5044,
#  'speak': 4689,
#  'soon': 4661,
#  'serena': 4434,
#  'sent': 4428,
#  'email': 1879,
#  'address': 589,
#  'incomm': 2689,
#  'right': 4255,
#  'call': 1180,
#  'germani': 2294,
#  'penc': 3802,
#  'per': 3808,
#  'minut': 3322,
#  'fix': 2117,
#  'line': 3051,
#  'via': 5358,
#  'access': 564,
#  'number': 3594,
#  '0844': 45,
#  '861': 490,
#  '85': 484,
#  'prepay': 3975,
#  'direct': 1696,
#  'said': 4328,
#  'choos': 1325,
#  'futur': 2247,
#  'sorri': 4670,
#  'din': 1688,
#  'lock': 3082,
#  'keypad': 2897,
#  'pub': 4051,
#  'go': 2328,
#  'sleep': 4576,
#  'tire': 5089,
#  'travel': 5171,
#  'tessi': 5003,
#  'pl': 3863,
#  'favor': 2056,
#  'convey': 1463,
#  'birthday': 996,
#  'wish': 5549,
#  'nimya': 3539,
#  'dnt': 1729,
#  'forget': 2169,
#  'today': 5108,
#  'shija': 4482,
#  'lara': 2978,
#  'loan': 3078,
#  'lt': 3140,
#  'gt': 2405,
#  'yunni': 5697,
#  'goin': 2334,
#  'late': 2986,
#  'dear': 1600,
#  'cute': 1559,
#  'thought': 5059,
#  'friendship': 2213,
#  'necessari': 3489,
#  'share': 4467,
#  'everi': 1955,
#  'secret': 4401,
#  'ur': 5306,
#  'close': 1362,
#  'frnd': 2216,
#  'thank': 5020,
#  'tesco': 5002,
#  'quit': 4084,
#  'nice': 3526,
#  'gone': 2341,
#  'ha': 2426,
#  'would': 5597,
#  'say': 4365,
#  'read': 4137,
#  'anyth': 725,
#  'way': 5455,
#  'seem': 4409,
#  'judgement': 2852,
#  'save': 4363,
#  'friday': 2210,
#  'post': 3938,
#  'l8r': 2949,
#  'class': 1349,
#  'india': 2699,
#  'draw': 1781,
#  'seri': 4435,
#  'mani': 3212,
#  'year': 5659,
#  'south': 4680,
#  'african': 612,
#  'soil': 4631,
#  'love': 3124,
#  'work': 5586,
#  'home': 2562,
#  'boooo': 1045,
#  'alway': 675,
#  'good': 2344,
#  'day': 1592,
#  'teeth': 4979,
#  'pain': 3738,
#  'maintain': 3196,
#  'oh': 3635,
#  'get': 2295,
#  'paid': 3737,
#  'outstand': 3716,
#  'one': 3660,
#  'commerci': 1408,
#  'hasbro': 2467,
#  'august': 829,
#  'made': 3181,
#  'us': 5316,
#  'jump': 2857,
#  'hoop': 2572,
#  'still': 4786,
#  'ok': 3640,
#  'need': 3493,
#  'tell': 4984,
#  'night': 3534,
#  'great': 2385,
#  'princess': 3999,
#  'think': 5045,
#  'hey': 2522,
#  'amk': 681,
#  'drink': 1788,
#  'tea': 4968,
#  'coffe': 1386,
#  'watch': 5447,
#  'co': 1377,
#  'that': 5026,
#  'kind': 2910,
#  'get4an18th': 2296,
#  'much': 3422,
#  'cold': 1392,
#  'dont': 1754,
#  'sad': 4321,
#  'scream': 4386,
#  'mean': 3255,
#  'shout': 4511,
#  'perform': 3813,
#  'done': 1752,
#  'oredi': 3692,
#  'free': 2195,
#  'top': 5137,
#  'rington': 4261,
#  'weekli': 5476,
#  '1st': 243,
#  'week': 5474,
#  'subpoli': 4842,
#  'hi': 2525,
#  'ass': 798,
#  'back': 871,
#  'tampa': 4947,
#  'prefer': 3969,
#  'kegger': 2888,
#  'freemsg': 2201,
#  'unlimit': 5285,
#  'activ': 582,
#  'smartcal': 4599,
#  'txt': 5224,
#  'help': 2509,
#  '08448714184': 46,
#  'stop': 4795,
#  'landlineonli': 2968,
#  'smile': 4603,
#  'pleasur': 3878,
#  'troubl': 5185,
#  'pour': 3948,
#  'rain': 4099,
#  'sum1': 4862,
#  'hurt': 2621,
#  'becoz': 936,
#  'someon': 4641,
#  'see': 4407,
#  'want': 5436,
#  'new': 3515,
#  'nokia': 3554,
#  '3510i': 321,
#  'colour': 1399,
#  'phone': 3834,
#  'deliveredtomorrow': 1629,
#  '300': 309,
#  'mobil': 3361,
#  '100': 196,
#  'text': 5008,
#  'camcord': 1192,
#  'repli': 4211,
#  '08000930705': 33,
#  'vote': 5399,
#  'wherev': 5512,
#  'heart': 2492,
#  'guid': 2413,
#  'yup': 5700,
#  'raviyog': 4125,
#  'peripher': 3816,
#  'bhayandar': 978,
#  'east': 1833,
#  'tomorrow': 5121,
#  'onward': 3666,
#  'eve': 1950,
#  'lolnic': 3090,
#  'went': 5490,
#  'fish': 2111,
#  'water': 5451,
#  'celebr': 1249,
#  'ny': 3605,
#  'famili': 2035,
#  'loxahatche': 3133,
#  'xma': 5630,
#  'tree': 5177,
#  'burn': 1149,
#  'updat': 5298,
#  'total': 5147,
#  'star': 4754,
#  'pa': 3731,
#  'knw': 2930,
#  'ru': 4301,
#  'neft': 3498,
#  'transact': 5164,
#  'refer': 4174,
#  'rs': 4297,
#  'decim': 1607,
#  'credit': 1514,
#  'beneficiari': 963,
#  'account': 570,
#  'time': 5087,
#  'jay': 2803,
#  'snicker': 4617,
#  'fuck': 2229,
#  'chord': 1327,
#  'even': 1951,
#  'spirit': 4707,
#  'bb': 915,
#  'tri': 5180,
#  'sure': 4889,
#  'aight': 635,
#  'latest': 2989,
#  'probabl': 4012,
#  'closer': 1364,
#  'tyler': 5232,
#  'two': 5223,
#  'trip': 5181,
#  'alright': 669,
#  'bring': 1105,
#  'min': 3311,
#  'let': 3026,
#  'god': 2332,
#  'pleas': 3876,
#  'complet': 1421,
#  'drug': 1796,
#  'lot': 3113,
#  'beauti': 933,
#  'wan': 5433,
#  'na': 3450,
#  'laid': 2962,
#  '2nite': 296,
#  'real': 4140,
#  'dog': 1739,
#  'locat': 3081,
#  'join': 2836,
#  'uk': 5244,
#  'largest': 2981,
#  'network': 3510,
#  'park': 3767,
#  '69696': 420,
#  'nyt': 3608,
#  'ec2a': 1839,
#  '3lp': 333,
#  'textbuddi': 5012,
#  'chat': 1278,
#  'horni': 2577,
#  'guy': 2419,
#  'area': 761,
#  '25p': 270,
#  'receiv': 4156,
#  'search': 4395,
#  'postcod': 3941,
#  'name': 3460,
#  '89693': 517,
#  'buy': 1157,
#  'egg': 1855,
#  'da': 1565,
#  'tick': 5078,
#  'could': 1480,
#  'die': 1678,
#  'loneli': 3095,
#  'know': 2928,
#  'pout': 3949,
#  'stomp': 4792,
#  'feet': 2071,
#  'ya': 5646,
#  'rememb': 4197,
#  'support': 4884,
#  'srt': 4742,
#  'thnk': 5052,
#  'ps3': 4044,
#  'play': 3871,
#  'usb': 5317,
#  'mate': 3236,
#  'spoke': 4716,
#  'mag': 3185,
#  'peopl': 3807,
#  'deliv': 1628,
#  'end': 1891,
#  'month': 3388,
#  '24th': 267,
#  'talk': 4942,
#  'later': 2988,
#  'lmao': 3074,
#  'wont': 5576,
#  'hair': 2433,
#  'anymor': 723,
#  'problem': 4013,
#  'spend': 4698,
#  'qualiti': 4077,
#  'togeth': 5110,
#  'knew': 2925,
#  'murder': 3436,
#  'exactli': 1979,
#  'unabl': 5253,
#  'cal': 1176,
#  'meet': 3268,
#  'bhaskar': 977,
#  'deep': 1614,
#  'ju': 2850,
#  'finish': 2102,
#  'bath': 908,
#  'regist': 4183,
#  'subscrib': 4843,
#  'yr': 5694,
#  'gift': 2305,
#  'voucher': 5400,
#  'enter': 1909,
#  'receipt': 4155,
#  'correct': 1473,
#  'an': 692,
#  'next': 3522,
#  'olymp': 3654,
#  '80062': 456,
#  'afternoon': 614,
#  'sunshin': 4875,
#  'dawn': 1591,
#  'refresh': 4179,
#  'happi': 2457,
#  'aliv': 658,
#  'breath': 1094,
#  'air': 637,
#  'matter': 3242,
#  'mind': 3314,
#  'reach': 4134,
#  'without': 5554,
#  'success': 4846,
#  'daddi': 1569,
#  'take': 4937,
#  'care': 1216,
#  'wat': 5446,
#  'make': 3198,
#  'thk': 5049,
#  'fall': 2033,
#  'actual': 583,
#  'prone': 4032,
#  'lucki': 3146,
#  'dad': 1568,
#  'ask': 792,
#  'come': 1401,
#  'fetch': 2077,
#  'alreadi': 668,
#  'leav': 3008,
#  'put': 4068,
#  'send': 4423,
#  'copi': 1470,
#  'report': 4213,
#  'crave': 1506,
#  'miss': 3329,
#  'ahmad': 631,
#  'saeed': 4323,
#  'al': 645,
#  'hallaq': 2440,
#  'learn': 3005,
#  'chang': 1265,
#  'convinc': 1464,
#  'wait': 5421,
#  'convers': 1461,
#  'role': 4279,
#  'life': 3037,
#  'felt': 2073,
#  'reason': 4149,
#  'ese': 1934,
#  'sake': 4329,
#  'tallahasse': 4944,
#  'coz': 1494,
#  'never': 3512,
#  'hand': 2445,
#  'hol': 2554,
#  'claim': 1343,
#  'med': 3264,
#  'holiday': 2559,
#  'stamp': 4750,
#  'self': 4415,
#  'envelop': 1917,
#  'po': 3888,
#  'box': 1064,
#  '113': 207,
#  'bray': 1086,
#  'wicklow': 5526,
#  'eir': 1861,
#  'quiz': 4085,
#  'start': 4757,
#  'saturday': 4360,
#  'unsub': 5292,
#  'emigr': 1883,
#  'someth': 4645,
#  'mayb': 3249,
#  'bit': 998,
#  'hope': 2574,
#  'mmmm': 3349,
#  'fair': 2027,
#  'weak': 5458,
#  'grin': 2390,
#  'push': 4065,
#  'knee': 2924,
#  'expos': 2006,
#  'belli': 956,
#  'pull': 4053,
#  'wick': 5524,
#  '8th': 523,
#  'fifti': 2087,
#  'use': 5319,
#  'foreign': 2166,
#  'countri': 1486,
#  'tmr': 5100,
#  'style': 4837,
#  'garment': 2269,
#  'di': 1668,
#  'yiju': 5676,
#  'pm': 3886,
#  'esaplanad': 1931,
#  'tonight': 5129,
#  'gal': 2257,
#  'dat': 1587,
#  'wif': 5528,
#  'yest': 5668,
#  'lol': 3089,
#  'despit': 1652,
#  'cramp': 1503,
#  'girl': 2310,
#  'set': 4440,
#  'soul': 4674,
#  'fire': 2106,
#  'spark': 4686,
#  'flame': 2123,
#  'big': 982,
#  'rawr': 4126,
#  'xoxo': 5631,
#  'purpos': 4063,
#  'homeown': 2563,
#  'tenant': 4993,
#  'welcom': 5484,
#  'previous': 3993,
#  'refus': 4180,
#  '0800': 29,
#  '1956669': 238,
#  'walk': 5426,
#  'citylink': 1341,
#  'faster': 2047,
#  'hungri': 2615,
#  'final': 2096,
#  'chanc': 1264,
#  'worth': 5593,
#  'discount': 1709,
#  'ye': 5657,
#  '85023': 485,
#  'savamob': 4362,
#  'member': 3278,
#  'offer': 3626,
#  'cs': 1530,
#  'pobox84': 3899,
#  'm263uz': 3168,
#  'sub': 4839,
#  '16': 233,
#  'better': 971,
#  'give': 2314,
#  'ive': 2773,
#  'ever': 1954,
#  'seen': 4410,
#  'babi': 867,
#  'common': 1410,
#  'room': 4284,
#  'noe': 3550,
#  'hous': 2590,
#  'date': 1588,
#  'sunday': 4868,
#  'sweet': 4912,
#  'sort': 4671,
#  'wen': 5487,
#  'lovabl': 3123,
#  'bcum': 927,
#  'angri': 700,
#  'wid': 5527,
#  'serious': 4437,
#  'childish': 1309,
#  'true': 5190,
#  'show': 4513,
#  'affect': 607,
#  'luv': 3157,
#  'kettoda': 2895,
#  'manda': 3206,
#  'sun': 4866,
#  'ah': 627,
#  'dun': 1813,
#  'anythin': 727,
#  'book': 1041,
#  'lesson': 3025,
#  'pilat': 3852,
#  'orchard': 3689,
#  'mrt': 3412,
#  'hor': 2576,
#  'uniform': 5274,
#  'lunch': 3152,
#  'eye': 2013,
#  'philosophi': 3831,
#  'okay': 3641,
#  'thanx': 5024,
#  'havent': 2477,
#  'got': 2357,
#  'topic': 5138,
#  'yet': 5670,
#  'rite': 4267,
#  'cant': 1205,
#  'job': 2831,
#  'idea': 2645,
#  'ooh': 3668,
#  '4got': 372,
#  'gon': 2339,
#  'danc': 1575,
#  'moseley': 3396,
#  'wed': 5468,
#  'cafe': 1173,
#  'nationwid': 3474,
#  'auto': 835,
#  'centr': 1253,
#  'newport': 3518,
#  'road': 4271,
#  'understand': 5263,
#  'wine': 5541,
#  'slurp': 4593,
#  'liao': 3030,
#  'moji': 3372,
#  'told': 5114,
#  'speechless': 4694,
#  'easili': 1832,
#  'length': 3019,
#  'behalf': 948,
#  'stun': 4835,
#  'exam': 1980,
#  'keep': 2887,
#  'touch': 5148,
#  'massag': 3231,
#  'oil': 3638,
#  'fave': 2055,
#  'posit': 3935,
#  'cours': 1489,
#  'stink': 4787,
#  'lousi': 3121,
#  'run': 4309,
#  'half': 2437,
#  'dead': 1597,
#  'hee': 2499,
#  'sale': 4333,
#  'arsen': 781,
#  'dartboard': 1585,
#  'condit': 1433,
#  'doubl': 1766,
#  'trebl': 5176,
#  'tv': 5214,
#  'babe': 866,
#  'urgent': 5308,
#  'import': 2674,
#  'inform': 2709,
#  'o2': 3609,
#  'user': 5321,
#  'find': 2098,
#  'log': 3084,
#  'onto': 3664,
#  'http': 2602,
#  'fantast': 2040,
#  'surpris': 4894,
#  'await': 848,
#  'sky': 4569,
#  'dark': 1580,
#  'excus': 1985,
#  'competit': 1416,
#  'internet': 2734,
#  'connect': 1444,
#  'slow': 4589,
#  'first': 2110,
#  'tomo': 5119,
#  'forc': 2164,
#  'eat': 1835,
#  'slice': 4582,
#  'realli': 4146,
#  'tho': 5055,
#  'suck': 4847,
#  'mark': 3223,
#  'worri': 5590,
#  'sick': 4527,
#  'turn': 5212,
#  'pizza': 3862,
#  'skype': 4570,
#  'wit': 5551,
#  'kz': 2946,
#  'sura': 4888,
#  'didnt': 1675,
#  'compani': 1413,
#  'given': 2315,
#  'ultimatum': 5247,
#  'countin': 1484,
#  'aburo': 557,
#  'enjoy': 1902,
#  'tot': 5146,
#  'paper': 3754,
#  'long': 3096,
#  'ago': 625,
#  'lar': 2977,
#  'haf': 2430,
#  'studi': 4829,
#  'stressful': 4811,
#  'laugh': 2991,
#  'may': 3248,
#  'add': 586,
#  'gud': 2409,
#  'ni8': 3524,
#  'swt': 4921,
#  'dream': 1783,
#  'fast': 2046,
#  'asleep': 796,
#  'tmrw': 5101,
#  'im': 2665,
#  'door': 1759,
#  'den': 1634,
#  'muz': 3443,
#  'plan': 3866,
#  'yan': 5651,
#  'jiu': 2827,
#  'place': 3864,
#  'suppos': 4885,
#  'wake': 5423,
#  'world': 5589,
#  'wonder': 5575,
#  'crazi': 1507,
#  'away': 851,
#  'lor': 3107,
#  'bedroom': 939,
#  'sed': 4406,
#  'sexi': 4446,
#  'mood': 3390,
#  'came': 1193,
#  'latr': 2990,
#  'cake': 1175,
#  'wife': 5529,
#  'surf': 4890,
#  'onlin': 3662,
#  'store': 4801,
#  'sometim': 4647,
#  'remembr': 4199,
#  'bcoz': 926,
#  'everyon': 1960,
#  'everytim': 1964,
#  'bslvyl': 1125,
#  'batt': 911,
#  'shop': 4501,
#  'ceil': 1247,
#  'ee': 1849,
#  'msg': 3413,
#  'poortiyagi': 3927,
#  'odalebeku': 3622,
#  'hanumanji': 2454,
#  'janarig': 2795,
#  'ivatt': 2772,
#  'kalisidar': 2875,
#  'olag': 3648,
#  'ondu': 3659,
#  'news': 3519,
#  'keluviri': 2889,
#  'maretar': 3221,
#  'ind': 2696,
#  'dodda': 1735,
#  'problum': 4016,
#  'nalli': 3459,
#  'siguviri': 4533,
#  'idu': 2652,
#  'matra': 3240,
#  'neglet': 3500,
#  'error': 1927,
#  'difficulti': 1684,
#  'contact': 1453,
#  'prize': 4008,
#  'guarante': 2408,
#  '09050001295': 122,
#  'land': 2966,
#  'a21': 535,
#  'valid': 5334,
#  '12hr': 217,
#  'monkey': 3383,
#  'wot': 5594,
#  'certainli': 1257,
#  'friend': 2211,
#  'mine': 3315,
#  'wiv': 5558,
#  'wud': 5618,
#  'annoyin': 710,
#  'servic': 4439,
#  'becausethey': 934,
#  'fanci': 2038,
#  'landlin': 2967,
#  'pobox1': 3891,
#  'w14rg': 5406,
#  '150p': 226,
#  'messag': 3292,
#  'ignor': 2657,
#  'custom': 1557,
#  'annonc': 707,
#  'deliveri': 1630,
#  '07046744435': 12,
#  'arrang': 777,
#  'well': 5485,
#  'meant': 3258,
#  'oppos': 3678,
#  'drunken': 1800,
#  'huh': 2609,
#  'also': 671,
#  'mistak': 3337,
#  'haha': 2431,
#  'hear': 2489,
#  'offici': 3628,
#  'market': 3224,
#  'fine': 2099,
#  'glad': 2316,
#  'ryder': 4314,
#  'gibb': 2303,
#  'nah': 3455,
#  'wednesday': 5471,
#  'mini': 3316,
#  'cheeto': 1292,
#  'bag': 876,
#  'accordingli': 569,
#  'repeat': 4208,
#  'word': 5585,
#  'toshiba': 5145,
#  'porteg': 3933,
#  'm100': 3165,
#  'gd': 2277,
#  'cool': 1467,
#  'dine': 1689,
#  'chase': 1276,
#  'cross': 1523,
#  'street': 4809,
#  'brin': 1104,
#  'aiya': 640,
#  'neva': 3511,
#  'properli': 4035,
#  'sheet': 4473,
#  'forward': 2179,
#  'tunji': 5210,
#  'queen': 4079,
#  'abiola': 547,
#  'brah': 1081,
#  'guess': 2412,
#  '09058097189': 137,
#  'reveal': 4241,
#  'pobox': 3890,
#  'ls15hb': 3137,
#  'blake': 1006,
#  'occur': 3620,
#  'jess': 2820,
#  'xxx': 5637,
#  'anywher': 730,
#  'damn': 1573,
#  'hunt': 2618,
#  'pretti': 3990,
#  'ladi': 2960,
#  'singl': 4545,
#  'exorc': 1992,
#  'emili': 1884,
#  'rose': 4287,
#  'hug': 2606,
#  'snog': 4618,
#  'yetti': 5671,
#  'fren': 2204,
#  '730': 439,
#  'last': 2984,
#  'trust': 5194,
#  'loverboy': 3127,
#  'pictur': 3847,
#  'ach': 572,
#  'feel': 2068,
#  'leg': 3013,
#  'faith': 2028,
#  'possibl': 3937,
#  'three': 5064,
#  'christma': 1331,
#  'merri': 3289,
#  'win': 5536,
#  'cash': 1230,
#  'wk': 5559,
#  'action': 581,
#  'custcar': 1556,
#  '08712405022': 83,
#  'sport': 4722,
#  'fan': 2037,
#  'str': 4804,
#  'plu': 3881,
#  'tone': 5124,
#  '8007': 457,
#  'norm': 3566,
#  'ca': 1170,
#  'cook': 1465,
#  'whole': 5520,
#  'electr': 1871,
#  'honey': 2566,
#  'heard': 2490,
#  'longer': 3097,
#  'crowd': 1524,
#  'advic': 601,
#  'cardiff': 1215,
#  'appt': 750,
#  'fault': 2053,
#  'listen': 3062,
#  'twice': 5218,
#  '250': 269,
#  'sm': 4594,
#  '84025': 480,
#  'web2mobil': 5463,
#  'etc': 1942,
#  'box139': 1066,
#  'la32wu': 2954,
#  'remov': 4202,
#  'txtx': 5231,
#  'snowboard': 4621,
#  'befor': 943,
#  'greet': 2388,
#  'affair': 606,
#  'cheer': 1288,
#  'avail': 839,
#  'wkli': 5562,
#  'soni': 4658,
#  'dvd': 1820,
#  'player': 3872,
#  'liverpool': 3071,
#  'mid': 3300,
#  'ansr': 714,
#  'sp': 4681,
#  'tyron': 5234,
#  'mandi': 3209,
#  'sullivan': 4860,
#  'hotmix': 2587,
#  'fm': 2147,
#  'chosen': 1328,
#  'easter': 1834,
#  'telephon': 4982,
#  '09041940223': 120,
#  'transfer': 5166,
#  'els': 1875,
#  'fli': 2131,
#  'goal': 2331,
#  'imagin': 2667,
#  'sink': 4546,
#  'pace': 3732,
#  'left': 3011,
#  'cage': 1174,
#  'cock': 1383,
#  'surround': 4896,
#  'remind': 4200,
#  'own': 3725,
#  'cuck': 1543,
#  'asap': 785,
#  'shuhui': 4521,
#  'bought': 1059,
#  'ron': 4283,
#  'present': 3979,
#  'swatch': 4907,
#  'project': 4025,
#  'applic': 744,
#  'airtel': 639,
#  'broadband': 1111,
#  'process': 4017,
#  'instal': 2724,
#  'happen': 2455,
#  'within': 5553,
#  'enough': 1907,
#  'voicemail': 5395,
#  '08719181503': 116,
#  'hello': 2506,
#  'decid': 1606,
#  'mp3': 3407,
#  'doesnt': 1737,
#  'scrape': 4383,
#  'barrel': 899,
#  'shower': 4514,
#  'social': 4627,
#  'misfit': 3327,
#  'goe': 2333,
#  'sip': 4547,
#  'cappuccino': 1211,
#  'kiss': 2919,
#  'across': 579,
#  'sea': 4394,
#  'nope': 3563,
#  'sinc': 4541,
#  'ayo': 858,
#  'forgotten': 2173,
#  'mmmmm': 3350,
#  'morn': 3394,
#  'sch': 4373,
#  'sathya': 4357,
#  'till': 5086,
#  'dint': 1693,
#  'saw': 4364,
#  'situat': 4555,
#  'vl': 5390,
#  'giv': 2313,
#  'kano': 2879,
#  'anyway': 729,
#  'salari': 4332,
#  '530': 392,
#  'dunno': 1815,
#  'ticket': 5079,
#  'shut': 4523,
#  'omg': 3655,
#  'yesterday': 5669,
#  'kid': 2906,
#  'boy': 1077,
#  'piss': 3859,
#  'diaper': 1671,
#  'caus': 1239,
#  'owe': 3723,
#  'face': 2017,
#  'cd': 1244,
#  '4u': 380,
#  'congratul': 1443,
#  'award': 850,
#  'freeentri': 2198,
#  'xt': 5632,
#  'music': 3439,
#  '87066': 494,
#  'tnc': 5103,
#  'old': 3651,
#  'live': 3069,
#  'high': 2528,
#  'marvel': 3229,
#  'ultim': 5246,
#  'game': 2259,
#  'spider': 4702,
#  '83338': 475,
#  '8ball': 520,
#  'wallpap': 5429,
#  'sir': 4549,
#  'letter': 3027,
#  'uncl': 5256,
#  'atlanta': 812,
#  'semest': 4420,
#  '545': 395,
#  'dinner': 1691,
#  'playng': 3874,
#  'race': 4091,
#  'ìï': 5714,
#  'strong': 4820,
#  'arm': 770,
#  'tht': 5072,
#  'wright': 5603,
#  'brother': 1117,
#  'return': 4239,
#  'immedi': 2670,
#  'regard': 4182,
#  'cover': 1492,
#  'pay': 3788,
#  'rent': 4204,
#  'bank': 891,
#  'authoris': 834,
#  'payment': 3791,
#  'sunoco': 4872,
#  'howard': 2593,
#  'meaning': 3256,
#  'compromis': 1425,
#  'everyth': 1962,
#  'pongal': 3918,
#  ...}

# %%
X_train_tf = tfidf.transform(X_train_resampled)
X_test_tf = tfidf.transform(X_test)

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
classifier_def  = LinearSVC()  # default C=1.0
classifier_def.fit(X_train_tf, y_train_resampled)

y_pred_train_def = classifier_def.predict(X_train_tf)
y_pred_test_def = classifier_def.predict(X_test_tf)

print("Train: ", accuracy_score(y_train_resampled, y_pred_train_def))
print("Test: ", accuracy_score(y_test, y_pred_test_def))
# Out:
# Train:  0.9995551601423488
# Test:  0.9775193798449613
# C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %%
from sklearn.model_selection import validation_curve

indices = np.arange(y_train_resampled.shape[0])
param_range=[0.04, 0.05, 0.06, 0.07, 0.08, 0.09 , 0.1]

train_scores, test_scores = validation_curve(LinearSVC(random_state=0), X_train_tf, y_train_resampled,
                                            param_name='C', param_range=param_range, cv=10, scoring='accuracy', n_jobs=-1)

# %%
print(train_scores)
# Out:
# [[0.98269896 0.98467622 0.98401714 0.98220465 0.98500824 0.98270181
#   0.98171334 0.98369028 0.98434926 0.98286656]
#  [0.98928983 0.98533531 0.98698303 0.98780689 0.98747941 0.98550247
#   0.98830313 0.98813839 0.98879736 0.98896211]
#  [0.99176141 0.99110232 0.98978415 0.99011369 0.98945634 0.99044481
#   0.98945634 0.99060956 0.99011532 0.99176277]
#  [0.99439776 0.9924205  0.99176141 0.99307958 0.99093904 0.99126853
#   0.99192751 0.99242175 0.99291598 0.99489292]
#  [0.99604548 0.99340913 0.99423299 0.99588071 0.99341021 0.99439868
#   0.99324547 0.99555189 0.99489292 0.99654036]
#  [0.99637502 0.99489207 0.99736365 0.99637502 0.99505766 0.99555189
#   0.99472817 0.99654036 0.99555189 0.99670511]
#  [0.99637502 0.99653979 0.99769319 0.99670456 0.99654036 0.99571664
#   0.99571664 0.99736409 0.99555189 0.99769357]]

# %%
print(test_scores)
# Out:
# [[0.97481481 0.97185185 0.97777778 0.97777778 0.97329377 0.97774481
#   0.97181009 0.98813056 0.98219585 0.98367953]
#  [0.97777778 0.97777778 0.98074074 0.9837037  0.97477745 0.98219585
#   0.97774481 0.98961424 0.98219585 0.9851632 ]
#  [0.97925926 0.98518519 0.9837037  0.98518519 0.97922849 0.98664688
#   0.97922849 0.98961424 0.98367953 0.9851632 ]
#  [0.98074074 0.98666667 0.98666667 0.98666667 0.98071217 0.98664688
#   0.98367953 0.9925816  0.9851632  0.98664688]
#  [0.98074074 0.98814815 0.99111111 0.99111111 0.98071217 0.9925816
#   0.98813056 0.9925816  0.98664688 0.98813056]
#  [0.98222222 0.99259259 0.99407407 0.99111111 0.9851632  0.99554896
#   0.99109792 0.99554896 0.98813056 0.98961424]
#  [0.98518519 0.99555556 0.99407407 0.99111111 0.99109792 0.99554896
#   0.9925816  0.99703264 0.98961424 0.99109792]]

# %%
import matplotlib.pyplot as plt
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title('Validation curve for SVM')
plt.xlabel('C')
plt.ylabel('Score')
plt.ylim(0.9, 1.1)
lw=2
plt.semilogx(
    param_range, train_scores_mean, label="Training score", color="darkorange", lw=lw
)
plt.fill_between(
    param_range,
    train_scores_mean - train_scores_std,
    train_scores_mean + train_scores_std,
    alpha=0.01,
    color="darkorange",
    lw=lw,
)
plt.semilogx(
    param_range, test_scores_mean, label="Cross-validation score", color="navy", lw=lw
)
plt.fill_between(
    param_range,
    test_scores_mean - test_scores_std,
    test_scores_mean + test_scores_std,
    alpha=0.01,
    color="navy",
    lw=lw,
)
plt.legend(loc="best")
plt.show()

# %%
from sklearn.model_selection import validation_curve

indices = np.arange(y_train.shape[0])
param_range=[0.2, .3, .4, .5,.6,.7,.8]

train_scores, test_scores = validation_curve(LinearSVC(random_state=0), X_train_tf, y_train_,
                                            param_name='C', param_range=param_range, cv=10, scoring='accuracy', n_jobs=-1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[109], line 6
#       3 indices = np.arange(y_train.shape[0])
#       4 param_range=[0.2, .3, .4, .5,.6,.7,.8]
# ----> 6 train_scores, test_scores = validation_curve(LinearSVC(random_state=0), X_train_tf, y_train,
#       7                                             param_name='C', param_range=param_range, cv=10, scoring='accuracy', n_jobs=-1)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:2295, in validation_curve(estimator, X, y, param_name, param_range, groups, cv, scoring, n_jobs, pre_dispatch, verbose, error_score, fit_params)
#    2142 @validate_params(
#    2143     {
#    2144         "estimator": [HasMethods(["fit"])],
#    (...)
#    2174     fit_params=None,
#    2175 ):
#    2176     """Validation curve.
#    2177
#    2178     Determine training and test scores for varying parameter values.
#    (...)
#    2293     The average test accuracy is 0.81
#    2294     """
# -> 2295     X, y, groups = indexable(X, y, groups)
#    2297     cv = check_cv(cv, y, classifier=is_classifier(estimator))
#    2298     scorer = check_scoring(estimator, scoring=scoring)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:514, in indexable(*iterables)
#     484 """Make arrays indexable for cross-validation.
#     485
#     486 Checks consistent length, passes through None, and ensures that everything
#    (...)
#     510 [[1, 2, 3], array([2, 3, 4]), None, <3x1 sparse matrix ...>]
#     511 """
#     513 result = [_make_indexable(X) for X in iterables]
# --> 514 check_consistent_length(*result)
#     515 return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [6744, 3870]

# %%
import matplotlib.pyplot as plt
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.title('Validation curve for SVM')
plt.xlabel('C')
plt.ylabel('Score')
plt.ylim(0.0, 1.1)
lw=2
plt.semilogx(
    param_range, train_scores_mean, label="Training score", color="darkorange", lw=lw
)
plt.fill_between(
    param_range,
    train_scores_mean - train_scores_std,
    train_scores_mean + train_scores_std,
    alpha=0.2,
    color="darkorange",
    lw=lw,
)
plt.semilogx(
    param_range, test_scores_mean, label="Cross-validation score", color="navy", lw=lw
)
plt.fill_between(
    param_range,
    test_scores_mean - test_scores_std,
    test_scores_mean + test_scores_std,
    alpha=0.2,
    color="navy",
    lw=lw,
)
plt.legend(loc="best")
plt.show()

# %%
clf = LinearSVC(C=.07, random_state=0)
clf.fit(X_train_tf, y_train_resampled)

y_pred_train = clf.predict(X_train_tf)
y_pred_test = clf.predict(X_test_tf)

train_acc = accuracy_score(y_train_resampled, y_pred_train)
test_acc = accuracy_score(y_test, y_pred_test)

print("Train: ", train_acc)
print("Test: ", test_acc)
# Out:
# Train:  0.9936239620403321
# Test:  0.9713178294573643
# C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %%
labels = ['Train', 'Test']
accuracies = [train_acc, test_acc]

plt.figure(figsize=(8, 6))
plt.bar(labels, accuracies, color=['blue', 'green'])
plt.ylim(0, 1)  # Đặt giới hạn trục y từ 0 đến 1
plt.ylabel('Accuracy')
plt.title('Comparison of Train vs Test Accuracy')
plt.show()

# %%
S
